# %% [raw]
# Load the Products.csv dataset

# %%
import pandas as pd
df=pd.read_csv('Products.csv')

# %% [raw]
# Display the first 10 rows of the dataset.

# %%
df.head(10)
# Out:
#    Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 0         101      Monitor      Accessories   1156    482     29  Brand C
# 1         102   Headphones         Clothing    289    305     45  Brand E
# 2         103      Charger  Home Appliances   4942    197    106  Brand E
# 3         104       Laptop         Clothing   1359    328    259  Brand E
# 4         105       Camera      Electronics   4382    204    166  Brand E
# 5         106       Laptop         Clothing   3038    182    213  Brand B
# 6         107      Charger      Accessories    963    324    118  Brand A
# 7         108      Charger      Electronics   4092    388    119  Brand A
# 8         109        Mouse  Home Appliances    482    400     11  Brand D
# 9         110      Charger         Clothing   2344    292    254  Brand B
#
#    Discount  Rating Launch Date  Warranty Period (Years)    Supplier  \
# 0      0.21     NaN  2020-07-20                      2.0         NaN
# ...

# %% [raw]
# Check the dimensions (number of rows and columns) of the DataFrame.

# %%
df.shape
# Out:
# (400, 14)

# %% [raw]
# Get the column names and data types of the dataset.

# %%
print(df.columns)
# Out:
# Index(['Product ID', 'Product Name', 'Category', 'Price', 'Stock', 'Sales',
#        'Brand', 'Discount', 'Rating', 'Launch Date', 'Warranty Period (Years)',
#        'Supplier', 'Product Description', 'Manufacture Country'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Product ID                   int64
# Product Name                object
# Category                    object
# Price                        int64
# Stock                        int64
# Sales                        int64
# Brand                       object
# Discount                   float64
# Rating                     float64
# Launch Date                 object
# Warranty Period (Years)    float64
# Supplier                    object
# Product Description         object
# Manufacture Country         object
# dtype: object

# %% [raw]
# Find out how many missing (null) values are in each column.

# %%
df.isnull().sum()
# Out:
# Product ID                  0
# Product Name                0
# Category                    0
# Price                       0
# Stock                       0
# Sales                       0
# Brand                       0
# Discount                    0
# Rating                     71
# Launch Date                 0
# Warranty Period (Years)    95
# Supplier                   96
# Product Description        76
# Manufacture Country        80
# dtype: int64

# %% [raw]
# Fill missing values in the 'Rating' column with the mean of the column.

# %%
df.fillna({'Rating':df['Rating'].mean()},inplace=True)
df.head(5)
# Out:
#    Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 0         101      Monitor      Accessories   1156    482     29  Brand C
# 1         102   Headphones         Clothing    289    305     45  Brand E
# 2         103      Charger  Home Appliances   4942    197    106  Brand E
# 3         104       Laptop         Clothing   1359    328    259  Brand E
# 4         105       Camera      Electronics   4382    204    166  Brand E
#
#    Discount    Rating Launch Date  Warranty Period (Years)    Supplier  \
# 0      0.21  2.993921  2020-07-20                      2.0         NaN
# 1      0.06  3.000000  2022-01-16                      1.0  Supplier B
# 2      0.07  2.993921  2024-11-11                      2.0  Supplier C
# 3      0.13  2.993921  2022-12-18                      NaN         NaN
# 4      0.34  2.993921  2024-08-26                      3.0  Supplier B
#
#   Product Description Manufacture Country
# 0       Best in class               India
# ...

# %% [raw]
# Find the product with the highest price in the dataset

# %%
df[df['Price']==df['Price'].max()][['Product Name','Price']]
# Out:
#     Product Name  Price
# 106      Monitor   4999

# %% [raw]
# Find all products with a price above the average price in the dataset

# %%
df[df['Price']>df['Price'].mean()][['Product Name','Price']]
# Out:
#     Product Name  Price
# 2        Charger   4942
# 4         Camera   4382
# 5         Laptop   3038
# 7        Charger   4092
# 10      Keyboard   4350
# ..           ...    ...
# 393     Keyboard   4314
# 394      Charger   2980
# 396     Keyboard   4762
# 398      Charger   3005
# 399      Monitor   3403
#
# [202 rows x 2 columns]

# %% [raw]
# Group the dataset by 'Category' and calculate the average price for each category

# %%
df.groupby('Category')['Price'].mean()
# Out:
# Category
# Accessories        2438.512821
# Clothing           2392.848101
# Electronics        2413.531646
# Furniture          2825.864865
# Home Appliances    2819.666667
# Name: Price, dtype: float64

# %% [raw]
#                                                             or

# %%
df.groupby('Category').agg({'Price':'mean'})
# Out:
#                        Price
# Category
# Accessories      2438.512821
# Clothing         2392.848101
# Electronics      2413.531646
# Furniture        2825.864865
# Home Appliances  2819.666667

# %% [raw]
# Find the category with the maximum average price

# %%
a=df.groupby('Category').agg({'Price':'mean'})
a[a['Price']==a['Price'].max()]
# Out:
#                  Price
# Category
# Furniture  2825.864865

# %%
df.head(5)
# Out:
#    Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 0         101      Monitor      Accessories   1156    482     29  Brand C
# 1         102   Headphones         Clothing    289    305     45  Brand E
# 2         103      Charger  Home Appliances   4942    197    106  Brand E
# 3         104       Laptop         Clothing   1359    328    259  Brand E
# 4         105       Camera      Electronics   4382    204    166  Brand E
#
#    Discount    Rating Launch Date  Warranty Period (Years)    Supplier  \
# 0      0.21  2.993921  2020-07-20                      2.0         NaN
# 1      0.06  3.000000  2022-01-16                      1.0  Supplier B
# 2      0.07  2.993921  2024-11-11                      2.0  Supplier C
# 3      0.13  2.993921  2022-12-18                      NaN         NaN
# 4      0.34  2.993921  2024-08-26                      3.0  Supplier B
#
#   Product Description Manufacture Country
# 0       Best in class               India
# ...

# %% [raw]
# Find the count of products in each category.

# %%
df.groupby('Category')['Product Name'].size()
# Out:
# Category
# Accessories        78
# Clothing           79
# Electronics        79
# Furniture          74
# Home Appliances    90
# Name: Product Name, dtype: int64

# %% [raw]
# Find the most expensive product in each category

# %%
a=df.groupby('Category')['Price'].idxmax()

df.loc[a]
# Out:
#      Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 74          175   Smartwatch      Accessories   4964    475     57  Brand C
# 52          153       Camera         Clothing   4959    147    104  Brand B
# 39          140     Keyboard      Electronics   4833    115    156  Brand A
# 84          185      Monitor        Furniture   4945     47    297  Brand D
# 106         207      Monitor  Home Appliances   4999    311    149  Brand A
#
#      Discount  Rating Launch Date  Warranty Period (Years)    Supplier  \
# 74       0.15     1.0  2024-09-15                      3.0  Supplier A
# 52       0.13     3.0  2021-04-03                      NaN         NaN
# 39       0.11     1.0  2023-11-18                      NaN  Supplier B
# 84       0.33     1.0  2021-08-07                      1.0         NaN
# 106      0.29     3.0  2024-05-01                      2.0         NaN
#
#     Product Description Manufacture Country
# ...

# %%
df.head(5)
# Out:
#    Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 0         101      Monitor      Accessories   1156    482     29  Brand C
# 1         102   Headphones         Clothing    289    305     45  Brand E
# 2         103      Charger  Home Appliances   4942    197    106  Brand E
# 3         104       Laptop         Clothing   1359    328    259  Brand E
# 4         105       Camera      Electronics   4382    204    166  Brand E
#
#    Discount    Rating Launch Date  Warranty Period (Years)    Supplier  \
# 0      0.21  2.993921  2020-07-20                      2.0         NaN
# 1      0.06  3.000000  2022-01-16                      1.0  Supplier B
# 2      0.07  2.993921  2024-11-11                      2.0  Supplier C
# 3      0.13  2.993921  2022-12-18                      NaN         NaN
# 4      0.34  2.993921  2024-08-26                      3.0  Supplier B
#
#   Product Description Manufacture Country
# 0       Best in class               India
# ...

# %% [raw]
# Find the most expensive product in each Category and Brand combination, including the Product Name, Price, and Category.

# %%
df.loc[df.groupby(['Category','Brand'])['Price'].idxmax()]
# Out:
#      Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 171         272      Charger      Accessories   4936    349    290  Brand A
# 302         403     Keyboard      Accessories   4529    361    162  Brand B
# 74          175   Smartwatch      Accessories   4964    475     57  Brand C
# 294         395      Charger      Accessories   4678    495    145  Brand D
# 311         412        Mouse      Accessories   4795    324     97  Brand E
# 229         330       Tablet         Clothing   4549    299    249  Brand A
# 52          153       Camera         Clothing   4959    147    104  Brand B
# 199         300   Smartwatch         Clothing   4851    120     77  Brand C
# 148         249       Laptop         Clothing   4588    416     71  Brand D
# 62          163       Camera         Clothing   4499    176    176  Brand E
# 39          140     Keyboard      Electronics   4833    115    156  Brand A
# ...

# %% [raw]
# For each Category, calculate the total number of products (Product Name), the average Price, and the total Stock Quantity.

# %%
df.groupby('Category').agg({"Product Name":'count',"Price":'mean','Stock':'sum'})
# Out:
#                  Product Name        Price  Stock
# Category
# Accessories                78  2438.512821  23582
# Clothing                   79  2392.848101  21379
# Electronics                79  2413.531646  21171
# Furniture                  74  2825.864865  17326
# Home Appliances            90  2819.666667  21663

# %%
df.head(5)
# Out:
#    Product ID Product Name         Category  Price  Stock  Sales    Brand  \
# 0         101      Monitor      Accessories   1156    482     29  Brand C
# 1         102   Headphones         Clothing    289    305     45  Brand E
# 2         103      Charger  Home Appliances   4942    197    106  Brand E
# 3         104       Laptop         Clothing   1359    328    259  Brand E
# 4         105       Camera      Electronics   4382    204    166  Brand E
#
#    Discount    Rating Launch Date  Warranty Period (Years)    Supplier  \
# 0      0.21  2.993921  2020-07-20                      2.0         NaN
# 1      0.06  3.000000  2022-01-16                      1.0  Supplier B
# 2      0.07  2.993921  2024-11-11                      2.0  Supplier C
# 3      0.13  2.993921  2022-12-18                      NaN         NaN
# 4      0.34  2.993921  2024-08-26                      3.0  Supplier B
#
#   Product Description Manufacture Country
# 0       Best in class               India
# ...

# %% [raw]
# For each Brand, calculate the following:
#
# The total count of products (Product Name).
# The highest Price.
# The lowest Stock

# %%
df.groupby('Brand').agg({'Product Name':'count','Price':'max','Stock':'min'})
# Out:
#          Product Name  Price  Stock
# Brand
# Brand A            70   4999     11
# Brand B            86   4959      4
# Brand C            69   4989      6
# Brand D            91   4958      3
# Brand E            84   4942      2

# %% [raw]
# For each Brand, calculate the total sales (multiply Price and Stock) and then find the brand with the highest total sales

# %%
df['Total_Sales']=df['Price']*df['Stock']
result=df.groupby('Brand').agg({'Total_Sales':'sum'})
result.loc[result.idxmax()]
# Out:
#          Total_Sales
# Brand
# Brand D     68676128

# %% [raw]
# Identify the Category that has the most unique Brands. Display the Category name along with the count of unique Brands.

# %%
df.groupby('Category')['Brand'].nunique()
# Out:
# Category
# Accessories        5
# Clothing           5
# Electronics        5
# Furniture          5
# Home Appliances    5
# Name: Brand, dtype: int64

# %% [raw]
# Find the top 3 Categories with the highest average Price. Display the Category name along with its average Price

# %%
result=df.groupby('Category').agg({'Price':'mean'})
result.nlargest(3,'Price')
# Out:
#                        Price
# Category
# Furniture        2825.864865
# Home Appliances  2819.666667
# Accessories      2438.512821
